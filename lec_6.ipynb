# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangyups/PyTorchZeroToAll/blob/main/lec_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn.functional as F
from torch.autograd import Variable

x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0], [4.0]]))
y_data = Variable(torch.Tensor([[0.], [0.], [1.], [1.]]))

class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear = torch.nn.Linear(1, 1)
    def forward(self, x):
        y_pred = F.sigmoid(self.linear(x))
        return y_pred
model = Model()

criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

for epoch in range(1000):
    y_pred = model(x_data)

    loss = criterion(y_pred, y_data)
    print(epoch, loss.item())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

hour_var = Variable(torch.Tensor([[1.0]]))
print("predict 1 hour ", 1.0, model(hour_var).item() > 0.5)
hour_var = Variable(torch.Tensor([[7.0]]))
print("predict 7 hour ", 7.0, model(hour_var).item() > 0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 0 0.6437374949455261
# 1 0.6420037746429443
# 2 0.6403012871742249
# 3 0.6386299729347229
# 4 0.6369892358779907
# 5 0.6353785991668701
# 6 0.633797824382782
# 7 0.6322463154792786
# 8 0.630723774433136
# 9 0.6292297840118408
# 10 0.6277638077735901
# 11 0.6263256072998047
# 12 0.6249146461486816
# 13 0.6235305070877075
# 14 0.6221727132797241
# 15 0.6208410263061523
# 16 0.6195349097251892
# 17 0.6182538270950317
# 18 0.6169976592063904
# 19 0.6157656311988831
# 20 0.6145576238632202
# 21 0.6133729815483093
# 22 0.6122113466262817
# 23 0.6110725402832031
# 24 0.6099557876586914
# 25 0.6088610887527466
# 26 0.6077876687049866
# 27 0.6067352890968323
# 28 0.605703592300415
# 29 0.6046919822692871
# 30 0.6037003993988037
# 31 0.6027281284332275
# ...

# %%
import torch
import torch.nn.functional as F
from torch.autograd import Variable

x_data = Variable(torch.Tensor([[-3.0], [-1.0], [3.0], [4.0],[5.0],[14.0]]))
y_data = Variable(torch.Tensor([[0.], [0.], [6.], [8.],[10.],[28.]]))

class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear = torch.nn.Linear(1, 1)
    def forward(self, x):
        y_pred = F.relu(self.linear(x))
        return y_pred
model = Model()

criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

for epoch in range(1000):
    y_pred = model(x_data)

    loss = criterion(y_pred, y_data)
    print(epoch, loss.item())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

hour_var = Variable(torch.Tensor([[1.0]]))
print("predict 1  ", model(hour_var).item())
hour_var = Variable(torch.Tensor([[-3.0]]))
print("predict -3  ", model(hour_var).item())
hour_var = Variable(torch.Tensor([[-5.0]]))
print("predict -5  ", model(hour_var).item())
hour_var = Variable(torch.Tensor([[-7.0]]))
print("predict -7  ", model(hour_var).item())
hour_var = Variable(torch.Tensor([[12.0]]))
print("predict 12  ", model(hour_var).item())
# Out:
# 0 166.1397247314453
# 1 165.97776794433594
# 2 165.82815551757812
# 3 165.68992614746094
# 4 165.56224060058594
# 5 165.4442901611328
# 6 165.33531188964844
# 7 165.23463439941406
# 8 165.14163208007812
# 9 165.0557098388672
# 10 164.97633361816406
# 11 164.9029998779297
# 12 164.8352508544922
# 13 164.77267456054688
# 14 164.71485900878906
# 15 164.6614532470703
# 16 164.6121063232422
# 17 164.56651306152344
# 18 164.52439880371094
# 19 164.48548889160156
# 20 164.4495391845703
# 21 164.4163360595703
# 22 164.38563537597656
# 23 164.3115997314453
# 24 163.3551483154297
# 25 119.7840805053711
# 26 3.60250186920166
# 27 0.26010653376579285
# 28 0.16133014857769012
# 29 0.15718230605125427
# 30 0.1558050662279129
# 31 0.15451939404010773
# 32 0.1532466858625412
# 33 0.15198440849781036
# 34 0.15073245763778687
# 35 0.14949087798595428
# 36 0.1482594758272171
# 37 0.14703793823719025
# 38 0.14582687616348267
# 39 0.14462582767009735
# 40 0.1434343010187149
# 41 0.1422528773546219
# ...
